# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('gulf_ships_BIG.csv')

# %%
data.head(10)
# Out:
#         MMSI              ShipName   Latitude  Longitude    Cog  TrueHeading  \
# 0   12345678  DMA                   25.261970  55.267157  241.2        511.0
# 1  210621000  WILLEM VAN ORANJE     25.356173  54.872110  127.1        130.0
# 2  222222222                   NaN  25.200367  55.227883  132.2        136.0
# 3  232032637  LEGENDE               25.209275  55.234998  315.3        323.0
# 4  232064711  PETROJARL ROSEBANK    25.247380  55.262697   92.0        122.0
# 5  235073785  CYBI ISLAND           25.177965  55.213382  249.8        227.0
# 6  244030951  GTO 202               25.174853  55.199940  360.0        511.0
# 7  244770069  COASTAL CHARIOT       25.192578  55.209305  353.3        264.0
# 8  244810178  CONQUEST MB1          25.260983  55.259467  266.0        511.0
# 9  245048000  COASTAL BOXER         25.172920  55.206765   47.7        262.0
#
#    ShipType  Draught  Length                        Time
# 0       NaN      NaN     NaN  2026-01-18T22:55:24.928317
# ...

# %%
data.drop('Time', axis=1)
# Out:
#          MMSI              ShipName   Latitude  Longitude    Cog  TrueHeading  \
# 0    12345678  DMA                   25.261970  55.267157  241.2        511.0
# 1   210621000  WILLEM VAN ORANJE     25.356173  54.872110  127.1        130.0
# 2   222222222                   NaN  25.200367  55.227883  132.2        136.0
# 3   232032637  LEGENDE               25.209275  55.234998  315.3        323.0
# 4   232064711  PETROJARL ROSEBANK    25.247380  55.262697   92.0        122.0
# ..        ...                   ...        ...        ...    ...          ...
# 71  636020243  MARSOL SCAMANDER      25.269532  55.256817  265.0        511.0
# 72  636020246  MONJASA SERVER        25.212695  55.065693  215.6        218.0
# 73  636021496  ZAKHER                25.444893  55.035067  113.4        263.0
# 74  636023914              CPG ALMA  25.264982  55.261677  113.9        192.0
# 75  720017000               MIDAS 7  25.271310  55.287680   33.9        511.0
#
#     ShipType  Draught  Length
# ...

# %%
df = data[data['ShipType'].notna()]

# %%
df.head(10)
# Out:
#          MMSI              ShipName   Latitude  Longitude    Cog  TrueHeading  \
# 3   232032637  LEGENDE               25.209275  55.234998  315.3        323.0
# 4   232064711  PETROJARL ROSEBANK    25.247380  55.262697   92.0        122.0
# 5   235073785  CYBI ISLAND           25.177965  55.213382  249.8        227.0
# 8   244810178  CONQUEST MB1          25.260983  55.259467  266.0        511.0
# 9   245048000  COASTAL BOXER         25.172920  55.206765   47.7        262.0
# 13  249552000  MATADOR UNO           25.268340  55.259327    NaN          NaN
# 14  256235000         MEIN SCHIFF 5  25.250927  55.267842  144.6        130.0
# 16  319015100               SUNRAYS  25.216028  55.232763  360.0        289.0
# 17  319029600  FALCON                25.261968  55.275690  135.1        358.0
# 19  319065700  BLISS                 25.210492  55.233920  173.5          4.0
#
#     ShipType  Draught  Length                        Time
# ...
