# %%
import pandas as pd
import json

# %%
with open('./marinetraffic_data_2.json', 'r') as f:
    json_data = json.load(f)

# %%
vessels = json_data['data']['rows']

# %%
df = pd.DataFrame(vessels)

# %%
df.head()
# Out:
#          LAT       LON SPEED COURSE HEADING ELAPSED DESTINATION FLAG LENGTH  \
# 0  37.964596  72.83345     1    312    None    1128     CLASS B   IN      0
#
#     SHIPNAME SHIPTYPE SHIP_ID WIDTH L_FORE W_LEFT
# 0  GIRIJA II        6  654975     0      0      0

# %%
df.set_index('SHIP_ID', inplace=True)

# %%
df.head()
# Out:
#                LAT       LON SPEED COURSE HEADING ELAPSED DESTINATION FLAG  \
# SHIP_ID
# 654975   37.964596  72.83345     1    312    None    1128     CLASS B   IN
#
#         LENGTH   SHIPNAME SHIPTYPE WIDTH L_FORE W_LEFT
# SHIP_ID
# 654975       0  GIRIJA II        6     0      0      0
