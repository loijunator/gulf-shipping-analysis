# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)

# %%
df = pd.read_csv('all_ships.csv')

# %%
df.head(20)
# Out:
#     SHIP_ID        LAT        LON  SPEED  COURSE  HEADING  ELAPSED  \
# 0    654975  37.964596  72.833450    1.0   312.0      NaN     1128
# 1    712039  22.637720  69.622772  106.0   234.0    242.0        3
# 2   2601376  22.323820  68.718918    0.0   238.0      3.0      235
# 3    417205  22.598110  69.278625  136.0   276.0    281.0        2
# 4    198486  22.590055  69.805664    0.0   137.0     46.0        5
# 5      1847  22.677912  69.935219   24.0    67.0     66.0        2
# 6   9581192  22.079887  68.794632  167.0    27.0     26.0        3
# 7    125579  22.505911  69.543892    0.0   180.0    101.0        2
# 8    458425  22.738251  69.700630    0.0     5.0    270.0        7
# 9    368418  22.501753  69.660019    3.0    88.0    358.0        3
# 10   212572  22.573967  69.678253    1.0    88.0    109.0        2
# 11   754761  22.846634  68.769302  121.0   300.0    297.0        5
# 12  4385468  21.616756  68.793381    5.0    34.0    359.0        7
# ...

# %%
df["TYPE_NAME"].unique()
# Out:
# array([nan, 'Tanker', 'Cargo Vessel', 'Tugs & Special Craft', 'Fishing',
#        'Passenger Vessel', 'Pleasure Craft', 'Unspecified Ship'],
#       dtype=object)

# %% [markdown]
# In the above command, we identify all possible shiptypes in the `TYPE_NAME` category, which is the fallback for `GT_SHIPTYPE`.
# Next, we will drop all ships that are of the categories - Tugs, Fishing, Passenger, Pleasure and Unspecified

# %%
# Out:
#                                                 SHIP_ID        LAT        LON  \
# 144   TmpnNE56WXlOamc0TnpZeU5qZzROdz09LWs1RFFMTWF5Wm...  40.279999  50.293335
# 145   TkRRek9Ua3dORFF6T1Rrd05EUXpPUT09LWllUGFTR3E5Zk...  40.338333  49.908333
# 146   T0RrME5ESXdPRGswTkRJd09EazBOQT09LUQ3SVlqWmNQNl...  40.353333  49.911667
# 147   TmpZd01UTXpOall3TVRNek5qWXdNUT09LUdOWWlmOXQ4YU...  40.193333  50.814999
# 148   Tmpnek1USXdOamd6TVRJd05qZ3pNUT09LVFNWTJpdlVzTW...  40.158333  50.076668
# ...                                                 ...        ...        ...
# 1848                                            8991946  27.530748  49.775887
# 1849                                            5399438  25.810844  55.949886
# 1850                                            5452316  26.341368  56.415421
# 1851  TVRZMU1qTXdNVFkxTWpNd01UWTFNZz09LUVsVFhZekNqbF...  26.340000  56.415001
# 1852                                            9894419  26.237427  50.215679
#
# ...

# %%
df["SHIPTYPE"].unique()
# Out:
# array([6, 8, 7, 3, 2, 1, 0, 9, 4])

# %%
df.drop_duplicates()
# Out:
#        SHIP_ID        LAT        LON  SPEED  COURSE  HEADING  ELAPSED  \
# 0       654975  37.964596  72.833450    1.0   312.0      NaN     1128
# 1       712039  22.637720  69.622772  106.0   234.0    242.0        3
# 2      2601376  22.323820  68.718918    0.0   238.0      3.0      235
# 3       417205  22.598110  69.278625  136.0   276.0    281.0        2
# 4       198486  22.590055  69.805664    0.0   137.0     46.0        5
# ...        ...        ...        ...    ...     ...      ...      ...
# 2894   6158657  12.566475  71.908226   63.0   266.0      NaN      873
# 2895   7172814  11.829759  74.488190   20.0   344.0      NaN      483
# 2896   9121134  13.737947  71.479797    0.0   233.0      NaN      520
# 2897  10265266  12.715636  72.070992    2.0     0.0      0.0      870
# 2898   9898940  10.872447  75.453323    1.0   297.0    297.0      134
#
#      DESTINATION FLAG  LENGTH              SHIPNAME  SHIPTYPE  WIDTH  L_FORE  \
# ...

# %%
df_final = df[(df.SHIPTYPE == 8) & (df.GT_SHIPTYPE >= 70)]

# %%
df_final
# Out:
#       SHIP_ID        LAT        LON  SPEED  COURSE  HEADING  ELAPSED  \
# 12    4385468  21.616756  68.793381    5.0    34.0    359.0        7
# 19     555604  21.955326  68.742577    1.0   299.0    230.0        7
# 36    5871848  21.753918  68.449768  130.0   159.0    159.0      101
# 38     729348  22.640388  69.948425    3.0    99.0      3.0        3
# 42     757479  22.002010  68.843094  103.0   343.0    342.0        2
# ...       ...        ...        ...    ...     ...      ...      ...
# 2321   992760  20.850328  71.571999    0.0   358.0     49.0        7
# 2322   194690  17.857080  71.186989  128.0   298.0    302.0      802
# 2354  8859095  16.381308  67.863266    6.0   234.0    283.0      512
# 2361   664327  15.027105  66.477867   86.0   144.0      NaN      735
# 2411   655878  21.157701  72.675285    0.0    69.0    270.0        3
#
#               DESTINATION FLAG  LENGTH         SHIPNAME  SHIPTYPE  WIDTH  \
# ...

# %%
df_final = df_final[(df_final.LAT > 24.0) & (df_final.LON < 58.0)]

# %%
df_final
# Out:
#       SHIP_ID        LAT        LON  SPEED  COURSE  HEADING  ELAPSED  \
# 433   9952487  25.983418  56.856281    0.0   242.0    242.0       67
# 442   5193035  24.579329  56.648533    0.0   136.0     28.0        9
# 447    714345  24.746080  56.536381    0.0   153.0     22.0        9
# 450    726479  25.357651  56.440666    0.0   243.0     40.0        6
# 509    753622  25.663824  57.055840    1.0   267.0    344.0        7
# ...       ...        ...        ...    ...     ...      ...      ...
# 1225   712801  25.883307  54.177692    0.0   301.0    302.0       14
# 1251   561488  26.044807  56.579006   73.0   184.0    182.0        2
# 1273  8786487  25.473209  55.178188    8.0    86.0      NaN      121
# 1315   766163  25.498449  53.958523   61.0   292.0      NaN       35
# 1342   507755  24.855259  56.569527    3.0    90.0      NaN       59
#
#             DESTINATION FLAG  LENGTH         SHIPNAME  SHIPTYPE  WIDTH  \
# ...
